# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  1.411745  4.391052  1.046240 -0.097155 -0.145004       1
# 1  2.648413  1.568671  1.841660 -0.227398 -2.381007       1
# 2  1.542846  3.531164  0.978334 -0.667963 -0.042532       1
# 3 -1.663389 -0.699716 -2.154184  0.476450  0.867252       0
# 4 -0.115684 -2.307469 -2.660456  1.900654  3.307523       0

# %%
# function for row sampling

def sample_rows(df,percent):
  return df.sample(int(percent*df.shape[0]),replace=True)

# %%
df1 = sample_rows(df,0.2)

# %%
df2 = sample_rows(df,0.2)

# %%
df3 = sample_rows(df,0.2)

# %%
df1.shape
# Out:
# (20, 6)

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:5],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:5],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:5],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.6, 0.8333333333333334, 'x[2] <= -0.196\ngini = 0.48\nsamples = 20\nvalue = [12, 8]'),
#  Text(0.4, 0.5, 'x[1] <= 4.78\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.5, 0.6666666666666667, 'True  '),
#  Text(0.2, 0.16666666666666666, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.6, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.7, 0.6666666666666667, '  False')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.6666666666666666, 0.875, 'x[3] <= 0.021\ngini = 0.48\nsamples = 20\nvalue = [8, 12]'),
#  Text(0.5, 0.625, 'x[3] <= -1.041\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.5833333333333333, 0.75, 'True  '),
#  Text(0.3333333333333333, 0.375, 'x[1] <= 0.862\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.16666666666666666, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.8333333333333334, 0.625, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.75, 0.75, '  False')]

# %%
plot_tree(clf3)
# Out:
# [Text(0.5, 0.75, 'x[3] <= 0.056\ngini = 0.455\nsamples = 20\nvalue = [7, 13]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.625, 0.5, '  False')]

# %%
clf1.predict(np.array([1.411745, 4.391052, 1.046240, -0.097155, -0.145004]).reshape(1,5))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf2.predict(np.array([1.411745, 4.391052, 1.046240, -0.097155, -0.145004]).reshape(1,5))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf3.predict(np.array([1.411745, 4.391052, 1.046240, -0.097155, -0.145004]).reshape(1,5))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])
