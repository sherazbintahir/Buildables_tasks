# %%
import pandas as pd

# %%
data = pd.read_csv('BostonHousing.csv')

# %%
data.sample(5)
# Out:
#          crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 439   9.39063  0.0  18.10     0  0.740  5.627   93.9  1.8172   24  666
# 468  15.57570  0.0  18.10     0  0.580  5.926   71.0  2.9084   24  666
# 400  25.04610  0.0  18.10     0  0.693  5.987  100.0  1.5888   24  666
# 360   4.54192  0.0  18.10     0  0.770  6.398   88.0  2.5182   24  666
# 21    0.85204  0.0   8.14     0  0.538  5.965   89.2  4.0123    4  307
#
#      ptratio       b  lstat  medv
# 439     20.2  396.90  22.88  12.8
# 468     20.2  368.74  18.13  19.1
# 400     20.2  396.90  26.77   5.6
# 360     20.2  374.56   7.79  25.0
# 21      21.0  392.53  13.83  19.6

# %%
data.shape
# Out:
# (506, 14)

# %%
data.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         5
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
X_boston, Y_boston = data.iloc[:,:-1],data.iloc[:,-1]

# %%
print("dataset feature names: " , X_boston.columns)
print("dataset target name: ", Y_boston.name)
# Out:
# dataset feature names:  Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat'],
#       dtype='object')
# dataset target name:  medv

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X_boston, Y_boston , train_size=0.80, test_size=0.20, random_state=123)
print('Train/Test Sets Sizes : ',X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# Train/Test Sets Sizes :  (404, 13) (102, 13) (404,) (102,)

# %%
print(X_train.isnull().sum())
print(Y_train.isnull().sum())
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         5
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# dtype: int64
# 0

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="mean")  # could also use "median"
X_train = imputer.fit_transform(X_train)
X_test  = imputer.transform(X_test)

# %%
lr = LinearRegression()
dt = DecisionTreeRegressor()
knn = KNeighborsRegressor()

# %%
lr.fit(X_train,Y_train)
dt.fit(X_train,Y_train)
knn.fit(X_train,Y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = dt.predict(X_test)
y_pred3 = knn.predict(X_test)

# %%
print("R^2 score for LR",r2_score(Y_test,y_pred1))
print("R^2 score for DT",r2_score(Y_test,y_pred2))
print("R^2 score for KNN",r2_score(Y_test,y_pred3))
# Out:
# R^2 score for LR 0.659349847609412
# R^2 score for DT 0.436966049972188
# R^2 score for KNN 0.5475962186976784

# %%
from sklearn.ensemble import BaggingRegressor

bag_regressor = BaggingRegressor(random_state=1)
bag_regressor.fit(X_train, Y_train)
# Out:
# BaggingRegressor(random_state=1)

# %%
Y_preds = bag_regressor.predict(X_test)

print('Training Coefficient of R^2 : %.3f'%bag_regressor.score(X_train, Y_train))
print('Test Coefficient of R^2 : %.3f'%bag_regressor.score(X_test, Y_test))
# Out:
# Training Coefficient of R^2 : 0.980
# Test Coefficient of R^2 : 0.820
